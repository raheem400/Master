# %%
#when user opens To Do List a welcome message should be displayed
#function for displaying the text message 'Welcome to To Do list'


def open_to_do_list(apps): #function defination   # The (apps) is the parameter
  x = ("Welcome to To Do list") # signature body
  print(x)
  print("1. Add your tasks")
  print("2. Mark tasks that you have completed")
  print("3. View your tasks for today")
  print("4. Remove tasks")
  print("5. Exit")
  return



  task = [] #Created an empty list to where added tasks will be added


#Function to add task to the list
def add_task(to_do_list):
  to_add_task=input("Enter task description:")
  if True:
    task.append(to_add_task)
    print("Task added")

#Function to mark task when completed
def mark_task_as_completed (to_do_list):
   # Get task index from user
    task_index = int(input("Enter the task to mark as complete: "))
    # Check if the index is valid
    if 0 <= task_index < len(todo_list):
        # Mark the task as complete
        todo_list[task_index]["completed"] = True
        print("Task has been completed. ")
    else:
        # Output invalid task
        print("Invalid task index. ")


# Function to view the tasks
def view_tasks(todo_list):
      print("To-do List: ")
      # Enumerate tasks starting from index 1
      for idx, item in enumerate(todo_list, start=1):
          # Using check marks to show complete or incomplete
          status = "\u2713" if item["completed"] else "\u2715"
          print(f"{idx}. {item['task']} [{status}]")

# Function to remove a task from the list
def remove_task(todo_list):
    # Display current tasks
    view_tasks(todo_list)
    # Get task index from user
    task_index = int(input("Enter the task you want to remove: ")) - 1
    if 0 <= task_index < len(todo_list):
        removed_task =todo_list.pop(task_index)
        print(f"Task '{removed_task['task']}' removed.")
    else:
        print("Invalid task index.")

todo_list = []

# This loop is to keep the program running
while True:

        # User choice is input
        choice = input("What you like to do from the above list: ")
        if choice == "1":
            #adding a task
            add_task(todo_list),

        elif choice == "2":
            # Marking a task
            mark_task(todo_list),

        elif choice == "3":
            # Viewing the tasks
            view_tasks(todo_list),

        elif choice == "4":
            # Removing user task
            remove_task(todo_list),

        elif choice == "5":
            # This is to exit the program
            print("Exiting..."),
            break # this is to break the loop
        else:
            print("Choose the correct input.")

# %%
open_to_do_list('apps') # The function being used to do display text and liist of actions.
# Out:
# Welcome to To Do list
# 1. Add your tasks
# 2. Mark tasks that you have completed
# 3. View your tasks for today
# 4. Remove tasks
# 5. Exit

# %%
task = [] #Created an empty list to where added tasks will be added

def add_task(list_of_actions):
  to_add_task=input("Enter task description")
  if True:
    task.append(to_add_task) #When user prompts the task it adds it to the list
    print("task has been added")
    return to_add_task

# %%
add_task('list_of_actions') #When code runs the prompt will be added to the list

# %%
task #list of actions prompted
# Out:
# []
